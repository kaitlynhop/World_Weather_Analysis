# %%
## Import the dependencies.
# random number generator
import numpy as np
import random
# Retrieve nearest city
from citipy import citipy
# For API Call
import requests
import time
# API key
import sys
sys.path.append('..')
from config import weather_api_key
# Dataframe
import pandas as pd
from datetime import datetime

# %%
## Generate list of 2000 lat and long values with np and random
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
# zip lat and long values together and store as list
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
### Generate list of nearest cities with only unique values
# Initialize list to hold cities
cities = []
# loop through coordinates list to get nearest city name
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
 # Add uniques cities to list   
    if city not in cities:
        cities.append(city)

print(len(cities))
# Out:
# 739

# %%
### Make API call and gather data
# Initialize list to hold city data
city_data = []

# set counters to keep track
record_count = 1
set_count = 1

# base url for open weather map
base_url = "https://api.openweathermap.org/data/2.5/weather"

# %%
#Loop through cities list to get city for url code
params = {
        "appid": weather_api_key,
        "units": "imperial"
    }

# %%
#Loop through cities list to get city for url code
for i, city in enumerate(cities):
    
    #Set trackers
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    print(f"Processing record: {record_count} of set: {set_count} | {city}")
    record_count +=1
    # Build API Url for each city
    url_name = city.replace(" ","+")
    params["q"] = url_name
     #Attempt to parse JSON data and retreive desired information
    try:
        weather = requests.get(base_url, params=params).json()
        city_lat = weather['coord']['lat']
        city_lng = weather['coord']['lon']
        city_max_temp = weather['main']['temp_max']
        city_humidity = weather['main']['humidity']
        city_clouds = weather['clouds']['all']
        city_wind = weather['wind']['speed']
        city_description = weather['weather'][0]['description']
        city_country = weather['sys']['country']
        # Attempt to make this freaking data list
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Descriptions": city_description})
    
    except:
        print(f"City: {city} error")
        print("Current number of cities in list:" + str(len(city_data)))
        pass
          
print("----------------- \n Method Complete \n ----------------")
# Out:
# Processing record: 1 of set: 1 | thinadhoo
# Processing record: 2 of set: 1 | lebu
# Processing record: 3 of set: 1 | nanortalik
# Processing record: 4 of set: 1 | busselton
# Processing record: 5 of set: 1 | yellowknife
# Processing record: 6 of set: 1 | yulara
# Processing record: 7 of set: 1 | noumea
# Processing record: 8 of set: 1 | dovers
# Processing record: 9 of set: 1 | victoria
# Processing record: 10 of set: 1 | vaini
# Processing record: 11 of set: 1 | albany
# Processing record: 12 of set: 1 | boromlya
# Processing record: 13 of set: 1 | hobart
# Processing record: 14 of set: 1 | hermanus
# Processing record: 15 of set: 1 | sobolevo
# Processing record: 16 of set: 1 | mareeba
# Processing record: 17 of set: 1 | maghama
# City: maghama error
# Current number of cities in list:16
# Processing record: 18 of set: 1 | sambava
# Processing record: 19 of set: 1 | jamestown
# Processing record: 20 of set: 1 | ca mau
# City: ca mau error
# Current number of cities in list:18
# Processing record: 21 of set: 1 | mataura
# Processing record: 22 of set: 1 | sapa
# Processing record: 23 of set: 1 | ushuaia
# Processing record: 24 of set: 1 | hilo
# Processing record: 25 of set: 1 | abu samrah
# City: abu samrah error
# Current number of cities in list:22
# Processing record: 26 of set: 1 | faanui
# Processing record: 27 of set: 1 | punta arenas
# City: punta arenas error
# Current number of cities in list:23
# Processing record: 28 of set: 1 | butaritari
# Processing record: 29 of set: 1 | port alfred
# City: port alfred error
# Current number of cities in list:24
# Processing record: 30 of set: 1 | barrow
# Processing record: 31 of set: 1 | saint anthony
# City: saint anthony error
# Current number of cities in list:25
# Processing record: 32 of set: 1 | pacific grove
# City: pacific grove error
# Current number of cities in list:25
# Processing record: 33 of set: 1 | atuona
# Processing record: 34 of set: 1 | new norfolk
# City: new norfolk error
# Current number of cities in list:26
# Processing record: 35 of set: 1 | esperance
# Processing record: 36 of set: 1 | kaitangata
# Processing record: 37 of set: 1 | bambous virieux
# City: bambous virieux error
# Current number of cities in list:28
# Processing record: 38 of set: 1 | nome
# Processing record: 39 of set: 1 | warri
# Processing record: 40 of set: 1 | cape town
# City: cape town error
# Current number of cities in list:30
# Processing record: 41 of set: 1 | venado tuerto
# City: venado tuerto error
# Current number of cities in list:30
# Processing record: 42 of set: 1 | hasaki
# Processing record: 43 of set: 1 | austin
# Processing record: 44 of set: 1 | upernavik
# Processing record: 45 of set: 1 | mahebourg
# Processing record: 46 of set: 1 | tarudant
# City: tarudant error
# Current number of cities in list:34
# Processing record: 47 of set: 1 | pisco
# Processing record: 48 of set: 1 | thompson
# Processing record: 49 of set: 1 | san patricio
# City: san patricio error
# Current number of cities in list:36
# Processing record: 50 of set: 1 | iwanai
# Processing record: 1 of set: 2 | kudahuvadhoo
# Processing record: 2 of set: 2 | norman wells
# City: norman wells error
# Current number of cities in list:38
# Processing record: 3 of set: 2 | cape elizabeth
# City: cape elizabeth error
# Current number of cities in list:38
# Processing record: 4 of set: 2 | fortuna
# Processing record: 5 of set: 2 | petauke
# Processing record: 6 of set: 2 | cidreira
# Processing record: 7 of set: 2 | huarmey
# Processing record: 8 of set: 2 | cherskiy
# Processing record: 9 of set: 2 | avarua
# Processing record: 10 of set: 2 | longyearbyen
# Processing record: 11 of set: 2 | kamenka
# Processing record: 12 of set: 2 | sorong
# Processing record: 13 of set: 2 | mrirt
# City: mrirt error
# Current number of cities in list:47
# Processing record: 14 of set: 2 | tasiilaq
# Processing record: 15 of set: 2 | safaqis
# City: safaqis error
# Current number of cities in list:48
# Processing record: 16 of set: 2 | sao joao da barra
# City: sao joao da barra error
# Current number of cities in list:48
# Processing record: 17 of set: 2 | codrington
# Processing record: 18 of set: 2 | fairbanks
# Processing record: 19 of set: 2 | tsihombe
# City: tsihombe error
# Current number of cities in list:50
# Processing record: 20 of set: 2 | rikitea
# Processing record: 21 of set: 2 | grand river south east
# City: grand river south east error
# Current number of cities in list:51
# Processing record: 22 of set: 2 | hallingby
# City: hallingby error
# Current number of cities in list:51
# Processing record: 23 of set: 2 | nurota
# Processing record: 24 of set: 2 | guerrero negro
# City: guerrero negro error
# Current number of cities in list:52
# Processing record: 25 of set: 2 | portland
# Processing record: 26 of set: 2 | tatawin
# Processing record: 27 of set: 2 | bagdarin
# Processing record: 28 of set: 2 | adrar
# Processing record: 29 of set: 2 | tyrma
# Processing record: 30 of set: 2 | baykit
# Processing record: 31 of set: 2 | ormara
# Processing record: 32 of set: 2 | leningradskiy
# Processing record: 33 of set: 2 | taolanaro
# City: taolanaro error
# Current number of cities in list:60
# Processing record: 34 of set: 2 | uvinza
# Processing record: 35 of set: 2 | muzhi
# Processing record: 36 of set: 2 | leesburg
# Processing record: 37 of set: 2 | severo-kurilsk
# Processing record: 38 of set: 2 | sentyabrskiy
# City: sentyabrskiy error
# Current number of cities in list:64
# Processing record: 39 of set: 2 | medvezhyegorsk
# Processing record: 40 of set: 2 | meulaboh
# Processing record: 41 of set: 2 | tuktoyaktuk
# Processing record: 42 of set: 2 | pennadam
# Processing record: 43 of set: 2 | riviere-au-renard
# Processing record: 44 of set: 2 | bredasdorp
# Processing record: 45 of set: 2 | qianan
# Processing record: 46 of set: 2 | sur
# Processing record: 47 of set: 2 | tongchuan
# Processing record: 48 of set: 2 | talnakh
# Processing record: 49 of set: 2 | dikson
# Processing record: 50 of set: 2 | tubruq
# City: tubruq error
# Current number of cities in list:75
# Processing record: 1 of set: 3 | basco
# Processing record: 2 of set: 3 | paradwip
# City: paradwip error
# Current number of cities in list:76
# Processing record: 3 of set: 3 | airai
# Processing record: 4 of set: 3 | laguna
# Processing record: 5 of set: 3 | tautira
# Processing record: 6 of set: 3 | college
# Processing record: 7 of set: 3 | olafsvik
# Processing record: 8 of set: 3 | narsaq
# Processing record: 9 of set: 3 | saskylakh
# Processing record: 10 of set: 3 | rundu
# Processing record: 11 of set: 3 | castro
# Processing record: 12 of set: 3 | hithadhoo
# Processing record: 13 of set: 3 | belushya guba
# City: belushya guba error
# Current number of cities in list:86
# Processing record: 14 of set: 3 | severnoye
# Processing record: 15 of set: 3 | prince rupert
# City: prince rupert error
# Current number of cities in list:87
# Processing record: 16 of set: 3 | mar del plata
# City: mar del plata error
# Current number of cities in list:87
# Processing record: 17 of set: 3 | berlevag
# Processing record: 18 of set: 3 | vila
# Processing record: 19 of set: 3 | kavieng
# Processing record: 20 of set: 3 | kruisfontein
# Processing record: 21 of set: 3 | east london
# City: east london error
# Current number of cities in list:91
# Processing record: 22 of set: 3 | deputatskiy
# Processing record: 23 of set: 3 | viedma
# Processing record: 24 of set: 3 | kapaa
# Processing record: 25 of set: 3 | whitehorse
# Processing record: 26 of set: 3 | tazovskiy
# Processing record: 27 of set: 3 | manbij
# Processing record: 28 of set: 3 | chokurdakh
# Processing record: 29 of set: 3 | beringovskiy
# Processing record: 30 of set: 3 | tiksi
# Processing record: 31 of set: 3 | doba
# Processing record: 32 of set: 3 | khatanga
# Processing record: 33 of set: 3 | torbay
# Processing record: 34 of set: 3 | bluff
# Processing record: 35 of set: 3 | nikolskoye
# Processing record: 36 of set: 3 | lompoc
# Processing record: 37 of set: 3 | novovarshavka
# Processing record: 38 of set: 3 | makakilo city
# City: makakilo city error
# Current number of cities in list:107
# Processing record: 39 of set: 3 | the valley
# City: the valley error
# Current number of cities in list:107
# Processing record: 40 of set: 3 | vardo
# Processing record: 41 of set: 3 | hwange
# Processing record: 42 of set: 3 | boromo
# Processing record: 43 of set: 3 | shadrinsk
# Processing record: 44 of set: 3 | necochea
# Processing record: 45 of set: 3 | sorland
# Processing record: 46 of set: 3 | neuquen
# Processing record: 47 of set: 3 | dudinka
# Processing record: 48 of set: 3 | port elizabeth
# City: port elizabeth error
# Current number of cities in list:115
# Processing record: 49 of set: 3 | muisne
# Processing record: 50 of set: 3 | balaipungut
# Processing record: 1 of set: 4 | lata
# Processing record: 2 of set: 4 | dunhua
# Processing record: 3 of set: 4 | atambua
# Processing record: 4 of set: 4 | marzuq
# Processing record: 5 of set: 4 | santarem
# Processing record: 6 of set: 4 | mahajanga
# Processing record: 7 of set: 4 | tatvan
# Processing record: 8 of set: 4 | westport
# Processing record: 9 of set: 4 | pemba
# Processing record: 10 of set: 4 | isilkul
# Processing record: 11 of set: 4 | tawang
# Processing record: 12 of set: 4 | luderitz
# Processing record: 13 of set: 4 | jumla
# Processing record: 14 of set: 4 | cap malheureux
# City: cap malheureux error
# Current number of cities in list:130
# Processing record: 15 of set: 4 | barbar
# City: barbar error
# Current number of cities in list:130
# Processing record: 16 of set: 4 | tabiauea
# City: tabiauea error
# Current number of cities in list:130
# Processing record: 17 of set: 4 | panguna
# Processing record: 18 of set: 4 | umzimvubu
# City: umzimvubu error
# Current number of cities in list:131
# Processing record: 19 of set: 4 | chuy
# Processing record: 20 of set: 4 | sibolga
# Processing record: 21 of set: 4 | andarab
# City: andarab error
# Current number of cities in list:133
# Processing record: 22 of set: 4 | ponta do sol
# City: ponta do sol error
# Current number of cities in list:133
# Processing record: 23 of set: 4 | illoqqortoormiut
# City: illoqqortoormiut error
# Current number of cities in list:133
# Processing record: 24 of set: 4 | tura
# Processing record: 25 of set: 4 | batagay-alyta
# Processing record: 26 of set: 4 | manzil tamim
# City: manzil tamim error
# Current number of cities in list:135
# Processing record: 27 of set: 4 | batagay
# Processing record: 28 of set: 4 | saint-philippe
# Processing record: 29 of set: 4 | seoul
# Processing record: 30 of set: 4 | billings
# Processing record: 31 of set: 4 | sola
# Processing record: 32 of set: 4 | pangnirtung
# Processing record: 33 of set: 4 | zhangdian
# Processing record: 34 of set: 4 | moroni
# Processing record: 35 of set: 4 | saint-georges
# Processing record: 36 of set: 4 | puerto ayora
# City: puerto ayora error
# Current number of cities in list:144
# Processing record: 37 of set: 4 | georgetown
# Processing record: 38 of set: 4 | rawannawi
# City: rawannawi error
# Current number of cities in list:145
# Processing record: 39 of set: 4 | kodiak
# Processing record: 40 of set: 4 | poum
# Processing record: 41 of set: 4 | carutapera
# Processing record: 42 of set: 4 | iqaluit
# Processing record: 43 of set: 4 | qaanaaq
# Processing record: 44 of set: 4 | maxixe
# Processing record: 45 of set: 4 | palmer
# Processing record: 46 of set: 4 | novaya igirma
# City: novaya igirma error
# Current number of cities in list:152
# Processing record: 47 of set: 4 | wanning
# Processing record: 48 of set: 4 | vikulovo
# Processing record: 49 of set: 4 | we
# City: we error
# Current number of cities in list:154
# Processing record: 50 of set: 4 | radcliff
# Processing record: 1 of set: 5 | inta
# Processing record: 2 of set: 5 | uyuni
# Processing record: 3 of set: 5 | vysokogornyy
# Processing record: 4 of set: 5 | mys shmidta
# City: mys shmidta error
# Current number of cities in list:158
# Processing record: 5 of set: 5 | nakhon phanom
# City: nakhon phanom error
# Current number of cities in list:158
# Processing record: 6 of set: 5 | moree
# Processing record: 7 of set: 5 | maningrida
# Processing record: 8 of set: 5 | pevek
# Processing record: 9 of set: 5 | aksarayskiy
# Processing record: 10 of set: 5 | barinas
# Processing record: 11 of set: 5 | rio gallegos
# City: rio gallegos error
# Current number of cities in list:163
# Processing record: 12 of set: 5 | matay
# Processing record: 13 of set: 5 | atka
# City: atka error
# Current number of cities in list:164
# Processing record: 14 of set: 5 | maumere
# Processing record: 15 of set: 5 | millington
# Processing record: 16 of set: 5 | haines junction
# City: haines junction error
# Current number of cities in list:166
# Processing record: 17 of set: 5 | yarada
# Processing record: 18 of set: 5 | sitka
# Processing record: 19 of set: 5 | souillac
# Processing record: 20 of set: 5 | santa maria
# City: santa maria error
# Current number of cities in list:169
# Processing record: 21 of set: 5 | glenwood springs
# City: glenwood springs error
# Current number of cities in list:169
# Processing record: 22 of set: 5 | kununurra
# Processing record: 23 of set: 5 | vostok
# Processing record: 24 of set: 5 | lotofaga
# Processing record: 25 of set: 5 | atherton
# Processing record: 26 of set: 5 | lagoa
# Processing record: 27 of set: 5 | sarahan
# Processing record: 28 of set: 5 | alofi
# Processing record: 29 of set: 5 | manokwari
# Processing record: 30 of set: 5 | barentsburg
# City: barentsburg error
# Current number of cities in list:177
# Processing record: 31 of set: 5 | alice springs
# City: alice springs error
# Current number of cities in list:177
# Processing record: 32 of set: 5 | nizhniy odes
# City: nizhniy odes error
# Current number of cities in list:177
# Processing record: 33 of set: 5 | avera
# Processing record: 34 of set: 5 | nizhneyansk
# City: nizhneyansk error
# Current number of cities in list:178
# Processing record: 35 of set: 5 | djambala
# Processing record: 36 of set: 5 | arraial do cabo
# City: arraial do cabo error
# Current number of cities in list:179
# Processing record: 37 of set: 5 | biaora
# Processing record: 38 of set: 5 | carnarvon
# Processing record: 39 of set: 5 | manuk mangkaw
# City: manuk mangkaw error
# Current number of cities in list:181
# Processing record: 40 of set: 5 | vanimo
# Processing record: 41 of set: 5 | zhuanghe
# Processing record: 42 of set: 5 | omsukchan
# Processing record: 43 of set: 5 | samusu
# City: samusu error
# Current number of cities in list:184
# Processing record: 44 of set: 5 | saleaula
# City: saleaula error
# Current number of cities in list:184
# Processing record: 45 of set: 5 | hambantota
# Processing record: 46 of set: 5 | bathsheba
# Processing record: 47 of set: 5 | touros
# Processing record: 48 of set: 5 | jalu
# Processing record: 49 of set: 5 | camacha
# Processing record: 50 of set: 5 | zonguldak
# Processing record: 1 of set: 6 | namie
# Processing record: 2 of set: 6 | victor rosales
# City: victor rosales error
# Current number of cities in list:191
# Processing record: 3 of set: 6 | aklavik
# Processing record: 4 of set: 6 | tsiroanomandidy
# Processing record: 5 of set: 6 | kefamenanu
# Processing record: 6 of set: 6 | emerald
# Processing record: 7 of set: 6 | pechenga
# Processing record: 8 of set: 6 | kalemie
# Processing record: 9 of set: 6 | constitucion
# Processing record: 10 of set: 6 | jonesboro
# Processing record: 11 of set: 6 | chernyshevskiy
# Processing record: 12 of set: 6 | vila franca do campo
# City: vila franca do campo error
# Current number of cities in list:200
# Processing record: 13 of set: 6 | champerico
# Processing record: 14 of set: 6 | esmeraldas
# Processing record: 15 of set: 6 | kirakira
# Processing record: 16 of set: 6 | farap
# Processing record: 17 of set: 6 | challapata
# Processing record: 18 of set: 6 | merauke
# Processing record: 19 of set: 6 | kudat
# Processing record: 20 of set: 6 | acari
# Processing record: 21 of set: 6 | bethel
# Processing record: 22 of set: 6 | cagayan de tawi-tawi
# City: cagayan de tawi-tawi error
# Current number of cities in list:209
# Processing record: 23 of set: 6 | ambilobe
# Processing record: 24 of set: 6 | burla
# Processing record: 25 of set: 6 | bandar-e lengeh
# City: bandar-e lengeh error
# Current number of cities in list:211
# Processing record: 26 of set: 6 | kahului
# Processing record: 27 of set: 6 | ostrovnoy
# Processing record: 28 of set: 6 | wagar
# Processing record: 29 of set: 6 | moose factory
# City: moose factory error
# Current number of cities in list:214
# Processing record: 30 of set: 6 | taoudenni
# Processing record: 31 of set: 6 | rocha
# Processing record: 32 of set: 6 | vila velha
# City: vila velha error
# Current number of cities in list:216
# Processing record: 33 of set: 6 | ilulissat
# Processing record: 34 of set: 6 | port lincoln
# City: port lincoln error
# Current number of cities in list:217
# Processing record: 35 of set: 6 | perpignan
# Processing record: 36 of set: 6 | mayahi
# Processing record: 37 of set: 6 | tuy hoa
# City: tuy hoa error
# Current number of cities in list:219
# Processing record: 38 of set: 6 | ribeira grande
# City: ribeira grande error
# Current number of cities in list:219
# Processing record: 39 of set: 6 | san cristobal
# City: san cristobal error
# Current number of cities in list:219
# Processing record: 40 of set: 6 | torzhok
# Processing record: 41 of set: 6 | bonavista
# Processing record: 42 of set: 6 | kamaishi
# Processing record: 43 of set: 6 | shirokiy
# Processing record: 44 of set: 6 | geraldton
# Processing record: 45 of set: 6 | celendin
# Processing record: 46 of set: 6 | hailun
# Processing record: 47 of set: 6 | floro
# Processing record: 48 of set: 6 | tapaua
# City: tapaua error
# Current number of cities in list:227
# Processing record: 49 of set: 6 | los llanos de aridane
# City: los llanos de aridane error
# Current number of cities in list:227
# Processing record: 50 of set: 6 | omboue
# Processing record: 1 of set: 7 | seoni malwa
# City: seoni malwa error
# Current number of cities in list:228
# Processing record: 2 of set: 7 | lykhivka
# Processing record: 3 of set: 7 | grand gaube
# City: grand gaube error
# Current number of cities in list:229
# Processing record: 4 of set: 7 | amarkantak
# Processing record: 5 of set: 7 | fevralsk
# City: fevralsk error
# Current number of cities in list:230
# Processing record: 6 of set: 7 | moche
# Processing record: 7 of set: 7 | paracuru
# Processing record: 8 of set: 7 | rohnert park
# City: rohnert park error
# Current number of cities in list:232
# Processing record: 9 of set: 7 | itarema
# Processing record: 10 of set: 7 | hovd
# Processing record: 11 of set: 7 | ust-maya
# Processing record: 12 of set: 7 | clyde river
# City: clyde river error
# Current number of cities in list:235
# Processing record: 13 of set: 7 | rio grande
# City: rio grande error
# Current number of cities in list:235
# Processing record: 14 of set: 7 | harlingen
# Processing record: 15 of set: 7 | marsh harbour
# City: marsh harbour error
# Current number of cities in list:236
# Processing record: 16 of set: 7 | kabansk
# Processing record: 17 of set: 7 | ituni
# City: ituni error
# Current number of cities in list:237
# Processing record: 18 of set: 7 | dakar
# Processing record: 19 of set: 7 | hirara
# Processing record: 20 of set: 7 | vakhrushi
# Processing record: 21 of set: 7 | ustyuzhna
# Processing record: 22 of set: 7 | cabo san lucas
# City: cabo san lucas error
# Current number of cities in list:241
# Processing record: 23 of set: 7 | lakatoro
# Processing record: 24 of set: 7 | yanam
# Processing record: 25 of set: 7 | nhulunbuy
# Processing record: 26 of set: 7 | barao de melgaco
# City: barao de melgaco error
# Current number of cities in list:244
# Processing record: 27 of set: 7 | ugoofaaru
# Processing record: 28 of set: 7 | la ronge
# City: la ronge error
# Current number of cities in list:245
# Processing record: 29 of set: 7 | phan rang
# City: phan rang error
# Current number of cities in list:245
# Processing record: 30 of set: 7 | bilibino
# Processing record: 31 of set: 7 | north adams
# City: north adams error
# Current number of cities in list:246
# Processing record: 32 of set: 7 | watertown
# Processing record: 33 of set: 7 | cherdyn
# Processing record: 34 of set: 7 | rawson
# Processing record: 35 of set: 7 | husavik
# Processing record: 36 of set: 7 | bengkulu
# Processing record: 37 of set: 7 | olinda
# Processing record: 38 of set: 7 | pangai
# Processing record: 39 of set: 7 | atar
# Processing record: 40 of set: 7 | challans
# Processing record: 41 of set: 7 | parras
# City: parras error
# Current number of cities in list:255
# Processing record: 42 of set: 7 | north battleford
# City: north battleford error
# Current number of cities in list:255
# Processing record: 43 of set: 7 | tombouctou
# Processing record: 44 of set: 7 | hunza
# City: hunza error
# Current number of cities in list:256
# Processing record: 45 of set: 7 | jaguey grande
# City: jaguey grande error
# Current number of cities in list:256
# Processing record: 46 of set: 7 | skibbereen
# Processing record: 47 of set: 7 | arsk
# Processing record: 48 of set: 7 | isangel
# Processing record: 49 of set: 7 | tessalit
# Processing record: 50 of set: 7 | grindavik
# Processing record: 1 of set: 8 | amapa
# Processing record: 2 of set: 8 | lasa
# Processing record: 3 of set: 8 | payo
# Processing record: 4 of set: 8 | vallenar
# Processing record: 5 of set: 8 | bilma
# Processing record: 6 of set: 8 | jutai
# Processing record: 7 of set: 8 | pochutla
# Processing record: 8 of set: 8 | koutiala
# Processing record: 9 of set: 8 | salalah
# Processing record: 10 of set: 8 | saldanha
# Processing record: 11 of set: 8 | narrabri
# Processing record: 12 of set: 8 | kapit
# Processing record: 13 of set: 8 | ahipara
# Processing record: 14 of set: 8 | mujiayingzi
# Processing record: 15 of set: 8 | bacuit
# City: bacuit error
# Current number of cities in list:275
# Processing record: 16 of set: 8 | coquimbo
# Processing record: 17 of set: 8 | sringeri
# Processing record: 18 of set: 8 | sabzevar
# Processing record: 19 of set: 8 | mecca
# Processing record: 20 of set: 8 | sangrur
# Processing record: 21 of set: 8 | salekhard
# Processing record: 22 of set: 8 | sao sepe
# City: sao sepe error
# Current number of cities in list:281
# Processing record: 23 of set: 8 | hovsan
# Processing record: 24 of set: 8 | catungan
# Processing record: 25 of set: 8 | gushikawa
# Processing record: 26 of set: 8 | pitimbu
# Processing record: 27 of set: 8 | bokspits
# City: bokspits error
# Current number of cities in list:285
# Processing record: 28 of set: 8 | krasnoselkup
# Processing record: 29 of set: 8 | herzogenbuchsee
# Processing record: 30 of set: 8 | balikpapan
# Processing record: 31 of set: 8 | chapais
# Processing record: 32 of set: 8 | lorengau
# Processing record: 33 of set: 8 | provideniya
# Processing record: 34 of set: 8 | yeniseysk
# Processing record: 35 of set: 8 | terney
# Processing record: 36 of set: 8 | riyadh
# Processing record: 37 of set: 8 | lusambo
# Processing record: 38 of set: 8 | qaqortoq
# Processing record: 39 of set: 8 | fukue
# Processing record: 40 of set: 8 | denpasar
# Processing record: 41 of set: 8 | nouadhibou
# Processing record: 42 of set: 8 | attawapiskat
# City: attawapiskat error
# Current number of cities in list:299
# Processing record: 43 of set: 8 | kieta
# Processing record: 44 of set: 8 | kambove
# Processing record: 45 of set: 8 | mahibadhoo
# Processing record: 46 of set: 8 | khorinsk
# Processing record: 47 of set: 8 | natal
# Processing record: 48 of set: 8 | norheimsund
# Processing record: 49 of set: 8 | sakaiminato
# Processing record: 50 of set: 8 | egvekinot
# Processing record: 1 of set: 9 | bandarbeyla
# Processing record: 2 of set: 9 | namatanai
# Processing record: 3 of set: 9 | okha
# Processing record: 4 of set: 9 | sabang
# Processing record: 5 of set: 9 | atenas
# Processing record: 6 of set: 9 | pedernales
# Processing record: 7 of set: 9 | palu
# Processing record: 8 of set: 9 | staroderevyankovskaya
# Processing record: 9 of set: 9 | sao joaquim
# City: sao joaquim error
# Current number of cities in list:315
# Processing record: 10 of set: 9 | boca do acre
# City: boca do acre error
# Current number of cities in list:315
# Processing record: 11 of set: 9 | katsuura
# Processing record: 12 of set: 9 | amahai
# Processing record: 13 of set: 9 | matara
# Processing record: 14 of set: 9 | masty
# Processing record: 15 of set: 9 | ardmore
# Processing record: 16 of set: 9 | ewo
# Processing record: 17 of set: 9 | mayskiy
# Processing record: 18 of set: 9 | samaro
# Processing record: 19 of set: 9 | kindu
# Processing record: 20 of set: 9 | sorvag
# City: sorvag error
# Current number of cities in list:324
# Processing record: 21 of set: 9 | palabuhanratu
# City: palabuhanratu error
# Current number of cities in list:324
# Processing record: 22 of set: 9 | santa marta
# City: santa marta error
# Current number of cities in list:324
# Processing record: 23 of set: 9 | litovko
# Processing record: 24 of set: 9 | dauphin
# Processing record: 25 of set: 9 | gunjur
# Processing record: 26 of set: 9 | florence
# Processing record: 27 of set: 9 | zyryanka
# Processing record: 28 of set: 9 | bezdan
# Processing record: 29 of set: 9 | kon tum
# City: kon tum error
# Current number of cities in list:330
# Processing record: 30 of set: 9 | zhezkazgan
# Processing record: 31 of set: 9 | tiznit
# Processing record: 32 of set: 9 | rong kwang
# City: rong kwang error
# Current number of cities in list:332
# Processing record: 33 of set: 9 | mehamn
# Processing record: 34 of set: 9 | george town
# City: george town error
# Current number of cities in list:333
# Processing record: 35 of set: 9 | minab
# Processing record: 36 of set: 9 | yantal
# Processing record: 37 of set: 9 | pahalgam
# Processing record: 38 of set: 9 | paragominas
# Processing record: 39 of set: 9 | itupiranga
# Processing record: 40 of set: 9 | abay
# Processing record: 41 of set: 9 | garden city
# City: garden city error
# Current number of cities in list:339
# Processing record: 42 of set: 9 | leh
# Processing record: 43 of set: 9 | jarjis
# City: jarjis error
# Current number of cities in list:340
# Processing record: 44 of set: 9 | mount gambier
# City: mount gambier error
# Current number of cities in list:340
# Processing record: 45 of set: 9 | miraflores
# Processing record: 46 of set: 9 | tibati
# Processing record: 47 of set: 9 | wajima
# Processing record: 48 of set: 9 | lavrentiya
# Processing record: 49 of set: 9 | tuatapere
# Processing record: 50 of set: 9 | bratsk
# Processing record: 1 of set: 10 | woodward
# Processing record: 2 of set: 10 | dauriya
# Processing record: 3 of set: 10 | mandan
# Processing record: 4 of set: 10 | burgeo
# Processing record: 5 of set: 10 | kayes
# Processing record: 6 of set: 10 | skelleftea
# Processing record: 7 of set: 10 | nador
# Processing record: 8 of set: 10 | taltal
# Processing record: 9 of set: 10 | skalistyy
# City: skalistyy error
# Current number of cities in list:354
# Processing record: 10 of set: 10 | gezing
# Processing record: 11 of set: 10 | fairview
# Processing record: 12 of set: 10 | auki
# Processing record: 13 of set: 10 | yingkou
# Processing record: 14 of set: 10 | talara
# Processing record: 15 of set: 10 | arroyo
# Processing record: 16 of set: 10 | vaitupu
# City: vaitupu error
# Current number of cities in list:360
# Processing record: 17 of set: 10 | hamilton
# Processing record: 18 of set: 10 | osoyoos
# Processing record: 19 of set: 10 | nakambala
# Processing record: 20 of set: 10 | bowmore
# Processing record: 21 of set: 10 | hit
# Processing record: 22 of set: 10 | strezhevoy
# Processing record: 23 of set: 10 | saint-augustin
# Processing record: 24 of set: 10 | labuhan
# Processing record: 25 of set: 10 | rostovka
# Processing record: 26 of set: 10 | baruun-urt
# Processing record: 27 of set: 10 | sahuaripa
# Processing record: 28 of set: 10 | vestmanna
# Processing record: 29 of set: 10 | darovskoy
# Processing record: 30 of set: 10 | rognan
# Processing record: 31 of set: 10 | guelengdeng
# City: guelengdeng error
# Current number of cities in list:374
# Processing record: 32 of set: 10 | biltine
# Processing record: 33 of set: 10 | gizo
# Processing record: 34 of set: 10 | barguzin
# Processing record: 35 of set: 10 | madimba
# Processing record: 36 of set: 10 | sao filipe
# City: sao filipe error
# Current number of cities in list:378
# Processing record: 37 of set: 10 | srednekolymsk
# Processing record: 38 of set: 10 | naze
# Processing record: 39 of set: 10 | poshekhonye
# Processing record: 40 of set: 10 | jambi
# Processing record: 41 of set: 10 | kayerkan
# Processing record: 42 of set: 10 | karari
# Processing record: 43 of set: 10 | marcona
# City: marcona error
# Current number of cities in list:384
# Processing record: 44 of set: 10 | gilazi
# City: gilazi error
# Current number of cities in list:384
# Processing record: 45 of set: 10 | caravelas
# Processing record: 46 of set: 10 | cabedelo
# Processing record: 47 of set: 10 | pangody
# Processing record: 48 of set: 10 | sibut
# Processing record: 49 of set: 10 | nantucket
# Processing record: 50 of set: 10 | kenai
# Processing record: 1 of set: 11 | lancaster
# Processing record: 2 of set: 11 | kuche
# City: kuche error
# Current number of cities in list:391
# Processing record: 3 of set: 11 | mangaratiba
# Processing record: 4 of set: 11 | nara
# Processing record: 5 of set: 11 | najran
# Processing record: 6 of set: 11 | flin flon
# City: flin flon error
# Current number of cities in list:394
# Processing record: 7 of set: 11 | buqayq
# City: buqayq error
# Current number of cities in list:394
# Processing record: 8 of set: 11 | ekpoma
# Processing record: 9 of set: 11 | kiunga
# Processing record: 10 of set: 11 | san rafael
# City: san rafael error
# Current number of cities in list:396
# Processing record: 11 of set: 11 | mugur-aksy
# Processing record: 12 of set: 11 | abha
# Processing record: 13 of set: 11 | agirish
# Processing record: 14 of set: 11 | ketchikan
# Processing record: 15 of set: 11 | florida
# Processing record: 16 of set: 11 | tefe
# Processing record: 17 of set: 11 | bontang
# Processing record: 18 of set: 11 | dolores
# Processing record: 19 of set: 11 | amderma
# City: amderma error
# Current number of cities in list:404
# Processing record: 20 of set: 11 | prainha
# Processing record: 21 of set: 11 | calama
# Processing record: 22 of set: 11 | esmeralda
# Processing record: 23 of set: 11 | namibe
# Processing record: 24 of set: 11 | salta
# Processing record: 25 of set: 11 | miguel alves
# City: miguel alves error
# Current number of cities in list:409
# Processing record: 26 of set: 11 | sulangan
# Processing record: 27 of set: 11 | san blas
# City: san blas error
# Current number of cities in list:410
# Processing record: 28 of set: 11 | simao
# Processing record: 29 of set: 11 | klaksvik
# Processing record: 30 of set: 11 | dehloran
# Processing record: 31 of set: 11 | shimoda
# Processing record: 32 of set: 11 | tahoua
# Processing record: 33 of set: 11 | quartucciu
# Processing record: 34 of set: 11 | tashtagol
# Processing record: 35 of set: 11 | evensk
# Processing record: 36 of set: 11 | calmar
# Processing record: 37 of set: 11 | puerto escondido
# City: puerto escondido error
# Current number of cities in list:419
# Processing record: 38 of set: 11 | penzance
# Processing record: 39 of set: 11 | puqi
# Processing record: 40 of set: 11 | conceicao do araguaia
# City: conceicao do araguaia error
# Current number of cities in list:421
# Processing record: 41 of set: 11 | plettenberg bay
# City: plettenberg bay error
# Current number of cities in list:421
# Processing record: 42 of set: 11 | heihe
# Processing record: 43 of set: 11 | cunha
# Processing record: 44 of set: 11 | muros
# Processing record: 45 of set: 11 | zadar
# Processing record: 46 of set: 11 | karachi
# Processing record: 47 of set: 11 | ngukurr
# City: ngukurr error
# Current number of cities in list:426
# Processing record: 48 of set: 11 | ucluelet
# Processing record: 49 of set: 11 | hutchinson
# Processing record: 50 of set: 11 | goderich
# Processing record: 1 of set: 12 | ternate
# Processing record: 2 of set: 12 | saint george
# City: saint george error
# Current number of cities in list:430
# Processing record: 3 of set: 12 | ijui
# Processing record: 4 of set: 12 | abong mbang
# City: abong mbang error
# Current number of cities in list:431
# Processing record: 5 of set: 12 | kimbe
# Processing record: 6 of set: 12 | ituango
# Processing record: 7 of set: 12 | vernon
# Processing record: 8 of set: 12 | terebovlya
# Processing record: 9 of set: 12 | sioux lookout
# City: sioux lookout error
# Current number of cities in list:435
# Processing record: 10 of set: 12 | hokitika
# Processing record: 11 of set: 12 | nemuro
# Processing record: 12 of set: 12 | hudson bay
# City: hudson bay error
# Current number of cities in list:437
# Processing record: 13 of set: 12 | shestakovo
# Processing record: 14 of set: 12 | tirana
# Processing record: 15 of set: 12 | slavyanka
# Processing record: 16 of set: 12 | launceston
# Processing record: 17 of set: 12 | akureyri
# Processing record: 18 of set: 12 | mantua
# Processing record: 19 of set: 12 | do gonbadan
# City: do gonbadan error
# Current number of cities in list:443
# Processing record: 20 of set: 12 | pavda
# City: pavda error
# Current number of cities in list:443
# Processing record: 21 of set: 12 | ginda
# Processing record: 22 of set: 12 | martapura
# Processing record: 23 of set: 12 | svetlyy
# Processing record: 24 of set: 12 | santiago del estero
# City: santiago del estero error
# Current number of cities in list:446
# Processing record: 25 of set: 12 | murgab
# Processing record: 26 of set: 12 | inhambane
# Processing record: 27 of set: 12 | surgut
# Processing record: 28 of set: 12 | vestmannaeyjar
# Processing record: 29 of set: 12 | tulsipur
# Processing record: 30 of set: 12 | da nang
# City: da nang error
# Current number of cities in list:451
# Processing record: 31 of set: 12 | khonuu
# City: khonuu error
# Current number of cities in list:451
# Processing record: 32 of set: 12 | kikwit
# Processing record: 33 of set: 12 | kotlas
# Processing record: 34 of set: 12 | yeppoon
# Processing record: 35 of set: 12 | willowmore
# Processing record: 36 of set: 12 | cap-aux-meules
# Processing record: 37 of set: 12 | tomatlan
# Processing record: 38 of set: 12 | guiren
# Processing record: 39 of set: 12 | isparta
# Processing record: 40 of set: 12 | mezen
# Processing record: 41 of set: 12 | georgiyevskoye
# Processing record: 42 of set: 12 | mayo
# Processing record: 43 of set: 12 | dingle
# Processing record: 44 of set: 12 | dali
# Processing record: 45 of set: 12 | yilan
# Processing record: 46 of set: 12 | zanjan
# Processing record: 47 of set: 12 | malinovoye ozero
# City: malinovoye ozero error
# Current number of cities in list:466
# Processing record: 48 of set: 12 | broome
# Processing record: 49 of set: 12 | maarianhamina
# Processing record: 50 of set: 12 | el balyana
# City: el balyana error
# Current number of cities in list:468
# Processing record: 1 of set: 13 | scottsburgh
# City: scottsburgh error
# Current number of cities in list:468
# Processing record: 2 of set: 13 | bijar
# Processing record: 3 of set: 13 | acarau
# Processing record: 4 of set: 13 | sechura
# Processing record: 5 of set: 13 | biala podlaska
# City: biala podlaska error
# Current number of cities in list:471
# Processing record: 6 of set: 13 | mandalgovi
# Processing record: 7 of set: 13 | kamenskoye
# City: kamenskoye error
# Current number of cities in list:472
# Processing record: 8 of set: 13 | hammerfest
# Processing record: 9 of set: 13 | gemena
# Processing record: 10 of set: 13 | umm jarr
# City: umm jarr error
# Current number of cities in list:474
# Processing record: 11 of set: 13 | acapulco
# Processing record: 12 of set: 13 | yatou
# Processing record: 13 of set: 13 | poya
# Processing record: 14 of set: 13 | tower
# Processing record: 15 of set: 13 | dhangadhi
# Processing record: 16 of set: 13 | sao felix do xingu
# City: sao felix do xingu error
# Current number of cities in list:479
# Processing record: 17 of set: 13 | umm kaddadah
# City: umm kaddadah error
# Current number of cities in list:479
# Processing record: 18 of set: 13 | suntar
# Processing record: 19 of set: 13 | hakkari
# Processing record: 20 of set: 13 | okhotsk
# Processing record: 21 of set: 13 | saint-leu
# Processing record: 22 of set: 13 | parsabad
# Processing record: 23 of set: 13 | kitimat
# Processing record: 24 of set: 13 | port augusta
# City: port augusta error
# Current number of cities in list:485
# Processing record: 25 of set: 13 | bud
# Processing record: 26 of set: 13 | hoquiam
# Processing record: 27 of set: 13 | yerbogachen
# Processing record: 28 of set: 13 | kaman
# Processing record: 29 of set: 13 | chomun
# City: chomun error
# Current number of cities in list:489
# Processing record: 30 of set: 13 | rafraf
# Processing record: 31 of set: 13 | outlook
# Processing record: 32 of set: 13 | grand-santi
# Processing record: 33 of set: 13 | havelock
# Processing record: 34 of set: 13 | sabha
# Processing record: 35 of set: 13 | aseri
# Processing record: 36 of set: 13 | itoman
# Processing record: 37 of set: 13 | olden
# Processing record: 38 of set: 13 | kharan
# Processing record: 39 of set: 13 | lashio
# Processing record: 40 of set: 13 | siocon
# Processing record: 41 of set: 13 | vagur
# Processing record: 42 of set: 13 | kyzyl
# Processing record: 43 of set: 13 | pangkalanbuun
# Processing record: 44 of set: 13 | lewisburg
# Processing record: 45 of set: 13 | rumoi
# Processing record: 46 of set: 13 | aksay
# Processing record: 47 of set: 13 | dong hoi
# City: dong hoi error
# Current number of cities in list:506
# Processing record: 48 of set: 13 | nyurba
# Processing record: 49 of set: 13 | faya
# Processing record: 50 of set: 13 | vao
# Processing record: 1 of set: 14 | leshukonskoye
# Processing record: 2 of set: 14 | katubao
# Processing record: 3 of set: 14 | eureka
# Processing record: 4 of set: 14 | lacolle
# Processing record: 5 of set: 14 | cam ranh
# City: cam ranh error
# Current number of cities in list:513
# Processing record: 6 of set: 14 | gidole
# Processing record: 7 of set: 14 | balkhash
# Processing record: 8 of set: 14 | mount isa
# City: mount isa error
# Current number of cities in list:515
# Processing record: 9 of set: 14 | luwuk
# Processing record: 10 of set: 14 | ati
# Processing record: 11 of set: 14 | beysehir
# Processing record: 12 of set: 14 | biograd na moru
# City: biograd na moru error
# Current number of cities in list:518
# Processing record: 13 of set: 14 | kutum
# Processing record: 14 of set: 14 | muscatine
# Processing record: 15 of set: 14 | mackay
# Processing record: 16 of set: 14 | quincy
# Processing record: 17 of set: 14 | nabire
# Processing record: 18 of set: 14 | suao
# City: suao error
# Current number of cities in list:523
# Processing record: 19 of set: 14 | cortez
# Processing record: 20 of set: 14 | atasu
# Processing record: 21 of set: 14 | cayenne
# Processing record: 22 of set: 14 | limerick
# Processing record: 23 of set: 14 | halalo
# City: halalo error
# Current number of cities in list:527
# Processing record: 24 of set: 14 | lyubeshiv
# City: lyubeshiv error
# Current number of cities in list:527
# Processing record: 25 of set: 14 | skagastrond
# City: skagastrond error
# Current number of cities in list:527
# Processing record: 26 of set: 14 | vilyuysk
# Processing record: 27 of set: 14 | wattegama
# Processing record: 28 of set: 14 | longlac
# City: longlac error
# Current number of cities in list:529
# Processing record: 29 of set: 14 | oranjestad
# Processing record: 30 of set: 14 | nogliki
# Processing record: 31 of set: 14 | malwan
# City: malwan error
# Current number of cities in list:531
# Processing record: 32 of set: 14 | tamandare
# Processing record: 33 of set: 14 | sayla
# Processing record: 34 of set: 14 | zhigansk
# Processing record: 35 of set: 14 | chagda
# City: chagda error
# Current number of cities in list:534
# Processing record: 36 of set: 14 | romanovo
# Processing record: 37 of set: 14 | coolum beach
# City: coolum beach error
# Current number of cities in list:535
# Processing record: 38 of set: 14 | alakurtti
# Processing record: 39 of set: 14 | kulachi
# Processing record: 40 of set: 14 | poco branco
# City: poco branco error
# Current number of cities in list:537
# Processing record: 41 of set: 14 | hailey
# Processing record: 42 of set: 14 | griffith
# Processing record: 43 of set: 14 | la paz
# City: la paz error
# Current number of cities in list:539
# Processing record: 44 of set: 14 | black river
# City: black river error
# Current number of cities in list:539
# Processing record: 45 of set: 14 | derzhavinsk
# Processing record: 46 of set: 14 | alotau
# City: alotau error
# Current number of cities in list:540
# Processing record: 47 of set: 14 | tshikapa
# Processing record: 48 of set: 14 | warqla
# City: warqla error
# Current number of cities in list:541
# Processing record: 49 of set: 14 | vilhena
# Processing record: 50 of set: 14 | voh
# Processing record: 1 of set: 15 | palana
# Processing record: 2 of set: 15 | vitorino freire
# City: vitorino freire error
# Current number of cities in list:544
# Processing record: 3 of set: 15 | ahuimanu
# Processing record: 4 of set: 15 | farah
# Processing record: 5 of set: 15 | coihaique
# Processing record: 6 of set: 15 | cambridge
# Processing record: 7 of set: 15 | kleck
# City: kleck error
# Current number of cities in list:548
# Processing record: 8 of set: 15 | gao
# Processing record: 9 of set: 15 | dodge city
# City: dodge city error
# Current number of cities in list:549
# Processing record: 10 of set: 15 | falealupo
# City: falealupo error
# Current number of cities in list:549
# Processing record: 11 of set: 15 | beloha
# Processing record: 12 of set: 15 | pasni
# Processing record: 13 of set: 15 | aykhal
# Processing record: 14 of set: 15 | aflu
# City: aflu error
# Current number of cities in list:552
# Processing record: 15 of set: 15 | rungata
# City: rungata error
# Current number of cities in list:552
# Processing record: 16 of set: 15 | itigi
# Processing record: 17 of set: 15 | kutiyana
# Processing record: 18 of set: 15 | katobu
# Processing record: 19 of set: 15 | ksenyevka
# City: ksenyevka error
# Current number of cities in list:555
# Processing record: 20 of set: 15 | kedrovyy
# Processing record: 21 of set: 15 | tallahassee
# Processing record: 22 of set: 15 | bosaso
# Processing record: 23 of set: 15 | ikongo
# Processing record: 24 of set: 15 | gat
# Processing record: 25 of set: 15 | dunedin
# Processing record: 26 of set: 15 | mataram
# Processing record: 27 of set: 15 | cururupu
# Processing record: 28 of set: 15 | kaniama
# Processing record: 29 of set: 15 | parati
# Processing record: 30 of set: 15 | korla
# Processing record: 31 of set: 15 | bjornevatn
# Processing record: 32 of set: 15 | minot
# Processing record: 33 of set: 15 | trenggalek
# Processing record: 34 of set: 15 | nyimba
# Processing record: 35 of set: 15 | long
# Processing record: 36 of set: 15 | kpandae
# Processing record: 37 of set: 15 | seshcha
# Processing record: 38 of set: 15 | ust-ilimsk
# Processing record: 39 of set: 15 | bunia
# -----------------
#  Method Complete
#  ----------------

# %%
## store city data as DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Thinadhoo      MV   0.5333   72.9333     82.87        67           6
# 1          Lebu      CL -37.6167  -73.6500     59.31        72           0
# 2    Nanortalik      GL  60.1432  -45.2371     28.24        76          41
# 3     Busselton      AU -33.6500  115.3333     66.40        80         100
# 4   Yellowknife      CA  62.4560 -114.3525     -4.45        40           0
# 5        Yulara      AU -25.2406  130.9889     69.64        37           0
# 6        Noumea      NC -22.2763  166.4572     81.00        99          96
# 7        Dovers      VC  12.8833  -61.1833     80.19        76           9
# 8      Victoria      HK  22.2855  114.1577     78.94        91          58
# 9         Vaini      TO -21.2000 -175.2000     80.76        74          20
# 10       Albany      US  42.6001  -73.9662     52.05        65          98
# 11     Boromlya      UA  50.6184   34.9704     38.41        92           3
# 12       Hobart      AU -42.8794  147.3294     53.06        93          20
# 13     Hermanus      ZA -34.4187   19.2345     59.81        71          77
# 14     Sobolevo      RU  54.4299   31.8996     35.19        87          21
# 15      Mareeba      AU -17.0000  145.4333     72.32        93         100
# 16      Sambava      MG -14.2667   50.1667     78.60        87          90
# 17    Jamestown      US  42.0970  -79.2353     39.52        69         100
# 18      Mataura      NZ -46.1927  168.8643     55.31        91          92
# 19         Sapa      PH   5.1544  120.3241     80.24        81          85
#
#     Wind Speed Current Descriptions
# 0        11.43            clear sky
# 1        13.40            clear sky
# 2         4.03     scattered clouds
# 3         7.14           light rain
# 4         0.00            clear sky
# 5         9.22            clear sky
# 6         9.75      overcast clouds
# 7        20.78            clear sky
# 8        10.00        broken clouds
# 9         8.05           few clouds
# 10       11.25      overcast clouds
# 11        1.52            clear sky
# 12        6.91           few clouds
# 13       15.48        broken clouds
# 14        9.35           few clouds
# 15        1.48           light rain
# 16        5.70           light rain
# 17        9.22                 mist
# 18        2.75      overcast clouds
# 19        2.06      overcast clouds

# %%
## Export DF as CSV
city_data_df.to_csv('WeatherPy_Database.csv', index_label="City_ID")
